# %%
import requests
import re
import pandas as pd
import time
import numpy as np

# %% [markdown]
# ##### Function to call the returnyoutubedislike api. This api is simply a website, where you plug in the video ID as seen in the 2nd line of the block. It returns a json object, where we can get various information about the given video, such as likes, dislikes, and viewcount.

# %%
def get_scores(id):
    r = requests.get(f"https://returnyoutubedislikeapi.com/votes?videoId={id}")
    vals = r.json()
    likes, dislikes, viewCount = vals["likes"], vals["dislikes"],vals["viewCount"]
    return likes,dislikes, viewCount

# %% [markdown]
# ##### Loops through all the video IDs (which are listed below this cell), and:
# ##### 1) Checks if the video is already in the dataframe.
# ##### 2) Checks if it's the first iteration. If thats true, then it creates a dataframe with the likes, dislikes, and viewcount.
# ##### 3) Continues to call the get_scores() functions on the ids, and updates the dataframe

# %%
#loop through all video IDS
for lort,i in enumerate(range(len(id))):
    #checks if video is in dataframe already (if it's created)
    try:
        if id[i] == df.videoId[i]:
            print(lort,"id already exists,continueing")
    except (NameError,KeyError):
        #If video not in the dataframe, then the get_scores() function is called to acquire the video's metrics that we want. 
        print(lort,id[i])
        likes,dislikes, viewCount = get_scores(id[i])
        #If it's the first iteration (and the ID is not in the dataframe), a dataframe is then constructed.
        if i == 0:
            d = {"videoId": id[i], "likes": likes,"dislikes": dislikes,"viewCount": viewCount}
            df = pd.DataFrame(data=d, index=[0])
        #After the first iteration: A temporary dataframe is constructed, and then appended to the original dataframe.
        else:
            temp_df = pd.DataFrame({"videoId": id[i], "likes": likes,"dislikes": dislikes,"viewCount": viewCount},index=[i])
            df = df.append(temp_df,ignore_index = True)
        #1 second wait time between each iteration, to avoid getting locked out from the API. 
        time.sleep(1)

# %% [markdown]
# ##### Save the dataframe to a csv file.

# %%
df.to_csv("Likes_Dislikes_Viewcount.csv")

# %% [markdown]
# ###### List of all the video IDs to loop through.

# %%
id =  ['_zUMrdXxJJA', 'DotnJ7tTA34', 'Gtl-6RCOl84', '-ojckacr9EA',
       'l3oWrNQo_Ng', 'OaQvsFIB4Uw', 'oHqfe3LcOOE', 'TftAFQflBy8',
       'vM-Bja2Gy04', 'OP_WC5oOCe8', 'UTc5I86to_8', 'Iwm0IO-NFRM',
       '9j_StJNMtu0', '_Gr2zXuEBL0', 'WHXq62VCaCM', 'VeAdKmTDsxQ',
       'e0snO6g1tdY', 'fFGS4zZWGoA', 'lvWgNSLIULw', 'FEchWX525Es',
       'nAg6RTQEfeM', 'JIThBMSABTo', 'a8M3GttfDn8', 'nPcyeDstbdk',
       'zRpHyvuJ__A', 'ooCxmWjhca8', 'oZQ8wJXPZvI', 'RHq0c7TZBH0',
       'wiQSsrQCG6c', 'Fqlz8QsNHC8', 'zutsDNxPJ8M', 'zpUTDuGIddQ',
       'azNDOKOsQro', 'aadqaw6vy24', 't3aDufvQh_c', '90eBBlt5-rc',
       'BaBbd_P--JM', 'FoKpTx5JPfA', 'm-1dyJFwNQw', 'z6LCD7nyD0s',
       'a45Xj7tfm8E', 'awztG587ghI', 'HzQCOcZkKJ8', 'fuNcrRMkwtQ',
       'ij1Xg2CIXtI', 'pvm7gpkx8MI', 'clk2ClBOGTM', 'TfNwbYxMUrI',
       'xgTpwPEggdg', '_9-oBrENwdQ', 'iang9SWVmdI', 'mepeWor5JPk',
       'QeoeTRm4Xes', '8f0P6iEHOrY', 'qiEp_hDqnrE', 'xFE8ASwxmpA',
       'EAvBT4N-mqc', 'F_64uKjZ324', 'WYkkfwbnpF0', 'SocRFvihFdg',
       'h-BU-kmmFJc', '5xyHF3H2MYU', '3JNwtsxcCAk', 'd971-CNiNXE',
       'sdytEqadkQY', 'J-797ZW4_y4', 'wA1pd1YT-9o', '5WJSjln30BQ',
       'LFn4HcnHPrU', 'S85Kvs8FSro', 'L-g-C6xtNVA', 'QxDX6oxyso0',
       'SiEy63chF60', '0IrHv6wrcRs', 'Tgkc2GC-Jwg', 'GsQ4gToL2aw',
       '1KMFZEGBaZY', 'VnNXTAmKbZM', 'bEg9lT0cj9Y', 'IlN5SMH5z4Q',
       'TO7tKXLDzvQ', '_3dEat5Q61s', 'k2nC7bepGpk', 'mfbNW_CxI8I',
       '_RuWIHDySTQ', 'vJick9OK7t8', 'VErCfg67sYQ', 'eI-ZlD3d4to',
       'x4P74JDGX_Y', '4-AlioPIaeY', 'FY2lrrL48ps', 'MCTed-h0oLI',
       'KyhujR6ucxw', 'ALAGG_eEA38', '-yNBZAN-gaI', '0y-1kDA1tLk',
       'GsbGER3FBJc', 'mFHLUdFut4I', 'b4Izfn3DphY', 'FmLnyyENhiw',
       'kZc0_2D4Io4', '_TQfaaOjFYQ', 'z4xXS8rWlOQ', 'PmGHbIcSUmc',
       'er0ZMdvmLYE', 'rPZn56I7Luk', 'krPnrI80RQM', 'Tzqnx8nLotE',
       'mFYloh57VhU', 'MH-ZNJCPdz4', 'acLTqMsHxFs', 'wzfW-HFy3Vw',
       'kmkWWRtG-og', 'HlMrHOFz8-U', 'L_U6_PqFDC4', 'EAcWAxQ9NT0',
       '-9oDEAQJt-o', 'YaLZxvmq0wA', 'yTqTHpIsb2E', 'LKqTYXGMloM',
       'SgwKZAMx_gM', 'gj5ibYSz8C0', 'dT0kexzmU7A', 'vrodN7I_Xko',
       'hf8EYbVxtCY', 'Od2NW1sfRdA', 'FBnkVJslRGo', '1qWUUGB7KUs',
       'htybz7XscIY', 'kDA-phXyYH8', 'Q33TkQKlIMg', 'Q73UhUTs6y0',
       '83ClbRPRDXU', 'KKXNmYoPkx0', 'vBHKSQ4MrJE', 'CNFm_DzHDaE',
       '1Qcm1UMjjoU', 'JtqIas3bYhg', 'BmllggGO4pM', 'NVHHs-xllqo',
       'aIsFywuZPoQ', 'aftysDQ4hpI', 'rK-JQU_bShc', '-QCFifHyXNM',
       'xDc_iartATY', 'Wpii7t26aZU', 'bKaj4gXor2M', 'E3E1URhCR60',
       'sTJfJoaZrCw', 'IZdjKKrMmaw', 'L23I_XopoA0', 'lzS8BQBcAu4',
       '51F0wfZBV0c', 'Pj0wz7zu3Ms', 'Ith2WetKXlg', '-aZBIpZY_Fw',
       'LRDPo0CHrko', 'jnJ4BGNpby8', 'bEyyKwVORvo', 'UKCmefQdplI',
       'pfhCEXLnQh8', 'B_XUlbPW-eY', 'WJPSSL2lSjU', 'QZLunQrxs9I',
       'zcI6SFiK_yk', 'TZ5NFlE_wd0', 'Fz7HmgPJQak', 'V0UlWZNp6cI',
       '1Q5CXN7soQg', 'PgSYux7UcXU', 'eHsWYmnXk1o', 'KfySe96FPr8',
       'ca00ZHJWKuA', 'OQSoII4Bj1o', 'Tm5uUzbUwR4', 'BYti8tb3rmI',
       'xppbyXSxPlo', 'MX6wAGuIMCg', '9U3BO8BoVhc', 'RbIxYm3mKzI',
       'i_1VW_0i6vo', 'asH6ny4ILzM', 'phQxK5u8IEs', 'Sel3fjl6uyo',
       'ULCIHP5dc44', 'R5546NL6gkE', 'Uafg97czxeQ', 'WR21TH-6LfY',
       'gpv7ayf_tyE', 'dpL5zS-PngE', 'tAJVDe205tY', 'QTIkUzkbzQk',
       '202KkD12AuI', '4CjJsX90yAU', 'fmjKsL_-rfw', '5Ux_ipIsNyo',
       '2kdqmzbqlVs', 'kCQxxqdowOg', '49_44FFKZ1M', 'UbhNxmwh_qc',
       'fXmAurh012s', '-voLo_TIWf4', 'sspsUdLrc-g', '2GVxxIsT4Y4',
       'uaaC57tcci0', 'PSmns9QWPiE', 'wyXnoeJoKLw', '7nxuEsx99-k',
       'X7MZuR8RM48', '820j10lEAec', 'bwHGegiFykU', '-Pwxr307O4w',
       '8nGcf4tBdF8', 'F1r6IDby3IE', '_R3LWM_Vt70', 'taE3PwurhYM',
       'hOiWSWLt-NA', 'rHmw87EpGIM', 'NaB_ERMAZu4', 'sY2TLiK27g4',
       'DqSdAgyF41k', 'ZTI6T5M8Fj0', 'M0O7lLe4SmA', 'umIeYcQLABg',
       'bsNIJd45jYM', 'A0gsjrcAi9w', 'G9AEE8NaEDw', 'NiFuJV2GLkY',
       '-j0rjlfmDx4', 'TgB7rMuxY-s', 'Af_Hj0MDBBQ', 'LR2Iq2VaZpM',
       '11DiQzSLfmo', 'vW2BPQ15OSw', '3VKESwIpzqk', 'gUHOSIe922E',
       'vIDbiQB6N28', '7q6Co-nd0lM', 'svp53UuEJHY', 'MysGjRS9jFU',
       'UyUuzCGblqc', 'j2rlnsGWGBU', 'fCGBZvcbzsI', 'BOe8L69JpVI',
       'kC72F1v_-WY', 'MYy7oGQiSqI', 'tJp5pLsXhgo', '9zG9RuJb3QU',
       '_kRab62q54M', 'YLE85olJjp8', 'b9EkMc79ZSU', '7FtDMn8BcvI',
       'DYY0QJhlXjc', 'W5QJW0M5pik', 'mjLWuzGVyew', '-NOp5ROn1HE',
       'T3mwUEoZdrI', '705yRfs6Dbs', 'Q-G1BME8FKw', 'u8ZsUivELbs',
       'PHqyFhrb3uU', '1zLKbMAZNGI', 'r9sSydb5ec8', 'bbtcUPJ_N4U',
       'HyOCCCbxwMQ', '1lXLGwe_DUU', 'DgvaXros3MY', 'st6r-8mLW_o',
       'b_m3jC4hGn0', 'f9OVdmIxkso', 'L8tCoWmooRE', 'QILhvR4QPsQ',
       'S5qJXYNNINo', 'kFIbSnJ9tQM', '3boMRfx6cjE', 'hcz6MNjTCE4',
       '2A5KtlZq7ws', 'aT7XzkO_CmM', '_TFc9pprTLE', 'hxaaAoI57fk',
       '8hq28cZ938E', '9pZrPauX_WM', '5fKn0Dhj64w', 'CI6MV7ZTCbg',
       'aYPUYVgwLWY', 'ax5YUmkWf_Y', 'dpLaoYw8xug', 'Nc6loZU3kjQ',
       'gZMOVvSkm44', 'Qe9B8kzlFjM', 'YaeDa_Uempk', 'hskfrLEkrxc',
       'mEEMbNS6fzY', '-JtwROpSVWc', '-zjikObAJHk', 'kk6f4enUo6w',
       '1d0Zf9sXlHk', 'nOMiQll5pQ0', '13nSISwxrY4', 'ieqemSsMxek',
       'LPgBQSya5rU', 'UMmfRJdPPoE', 'AmOheoEWjt4', '2Cwaneq2w-4',
       'N-QI4XU_Tys', 'oqxAJKy0ii4', 'A1PTIxYrTVw', 'YQ1vN_91KO0',
       'J6QEnsNMkks', '-qIlCo9yqpY', 'sB7LEqzXl_Y', '0DAmWHxeoKw',
       'HCtDkpe89aY', 'f-LKtOPn8U4', '65xa8TG2G8o', 'IN5TD4VRcSM',
       'EbptKdhRXEo', 'pyM3z73oMAk', 'A_apvQkWsVY', 'Xj2b0swdpX8',
       '_zxhK3Z-R0c', 'vRunUkdkK8s', 'XXuBwwZvruI', '27dZyLpY4xU',
       '_U2m1x5pmKM', 'EoGojQE4p-8', 'vKQzQ6fUkxU', 'dXpa5PrtuP0',
       'W0Zma6L9bfI', '7vUQYzZ_UZc', 'tI1JGPhYBS8', 'lCQimQfDuTs',
       'P-E-IGQCsPo', 'XIkQFUlBXF0', 'S7zP4ccVxYY', 'Mmq_NVwLN_g',
       'Hkb64KzON9E', 'CGZmwsK58M8', 'WTLgg8oRSBE', 'FHuHMwdHY8k',
       'uIdjcDTc9Vk', 'LhERIj0ddXI', 'dtohea4CFbE', 'RYmQHMC8NII',
       'omn2PJEuOTw', 'bUN5uSu_VQM', 'c_pHCqZkXvY', 'f2OGhJoypPw',
       'iXdw5wYI4cY', 'OMvNYm3g-tA', 'Sk5uBa68FAg', 'Nne2blorXnE',
       'XqTPaRz8Nx8', 'z-81WVD8xTs', 'pN8xZ5WDonk', 'UAA6VUtPNzk',
       'D4wJK4C_nZY', 'cH4mYC91omg', 'xltjtd4Tx1A', 'XIT1u0DxuRs',
       'fnn9zEQbqI0', 'QOTKWuIlmh8', '6Of1wKwGVPo', 'L2GVrR8233E',
       'jcQhT_HZx8s', '5vmaG3MUrYg', 'QFwJJywzbDs', 'HJ6iehLtmtY',
       'RKWQ2Pce74k', 'C57EJhgQ8t0', 'tFMQs50V1g8', 'DpZ3yZhsWZE',
       'MUpFzScK7P8', '79sHAvFiBt0', 'OWEgUhWU4g4', 'OGX8Jyjkj0o',
       'MgQUed4iEI8', 'INv-OQ1clmw', 'mrDe05g1bLU', 'VS3_UU-sWeM',
       'YBCOVyYo6VA', 'YM8zgY7sG_g', 'GlYxLChVy_0', 'ijsh5RVYnoY',
       'vOTDb9UqTa0', 'Z6ET4N6Sfhs', 'tLrwPjLlOjM', 'SRDGQZHsiGg',
       'OD3UhmRy4lg', 'EGsoC0bWakU', 'qNlrmBWY25Q', '-VVHUq4tOzg',
       'S1JmLvFWi0w', 'BmYhYPNbhtw', '0FKJNcV9Ym4', 'D7HrBvBJR-c',
       'SwAF6sYb94s', '1gvcNY5ywqw', 'ocYDDO_04lQ', 'E0JxDffw9J8',
       '_1PSRHVtmIo', 'gh0KJImjkqc', 'Aofd2grKYCs', 'ZpkRgaXNGyo',
       '-lnw6DFZTYo', 'IPNmW1Mug-4', 'xDlGkFoj1TY', 'Pi-dyFk5pgo',
       'nswae1s320k', 'Ptlg57Ilpso', '32g-9Jbwlc4', 'P1_KHFbCzIY',
       'iv3yDQ83Jcc', 'gn3gK27HIsw', 'BnpTgHVmH_0', 'qFn9Tmjj-hY',
       'HLdY__1EKic', 'YrdjmuREFrc', 'hz6stWWu6XI', 'Ahu3shMjKxE',
       'VgR3DLLm_j4', 'krv321vG4og', 'fZWoS5vW8J8', 'pYr2shJhO2Y',
       'oqZ3fq-hYxo', 'WluwGWAyfqU']
